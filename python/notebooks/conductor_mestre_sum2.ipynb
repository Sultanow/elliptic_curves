# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import colors
from sympy import sieve, prime, primerange
import itertools
import pandas as pd

# %%
df = pd.read_csv('C:/Users/esultano/git/elliptic_curves/data/prime_all_01990-01999.csv', header=None)
num_curves = df.shape[0]
mat = [None]*num_curves

# delete duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#                0  1  2  3      4        5         6
# 0  1990001058803  1  0  0 -59407  5567838  3.012359
# 1  1990001117021  1  0  0  -3786    58279  3.207060
# 2  1990001338837  0 -1  1  -3260   -21888  3.842878
# 3  1990002577411  1 -1  1  -8659   319622  3.079170
# 4  1990002949307  1  1  0 -72650  7506557  3.901594

# %%
max_conductor = df[0].max()

sortedlist = df[0].tolist()
sortedlist.sort()
df['primeidx'] = df[0].apply(lambda x: sortedlist.index(x))

# %%
df.head()
# Out:
#                0  1  2  3      4        5         6  primeidx
# 0  1990001058803  1  0  0 -59407  5567838  3.012359         0
# 1  1990001117021  1  0  0  -3786    58279  3.207060         1
# 2  1990001338837  0 -1  1  -3260   -21888  3.842878         2
# 3  1990002577411  1 -1  1  -8659   319622  3.079170         3
# 4  1990002949307  1  1  0 -72650  7506557  3.901594         4

# %%
df.sort_values("primeidx", inplace=True)
x = df["primeidx"].tolist()
y1 = df[6].tolist()

plt.figure(figsize=(24, 16))
plt.scatter(x, y1, color='blue', s=1)
plt.show()

# %%
df.sort_values(0, inplace=True)
x = df[0].tolist()
y1 = df[6].tolist()

plt.figure(figsize=(24, 16))
plt.scatter(x, y1, color='blue', s=1)
plt.show()

# %%
df.sort_values(0, inplace=True)
x = df[0].tolist()
y1 = df[4].tolist()

plt.figure(figsize=(24, 16))
plt.plot(x, y1, color='red')
plt.show()
