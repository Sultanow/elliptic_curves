# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import pchip, interp1d
from scipy import interpolate
from matplotlib.pyplot import figure
from matplotlib import colors
from sympy import sieve, prime, primerange
import itertools
import pandas as pd

# %%
df = pd.read_csv('C:/Users/amegahed/git/elliptic_curves/data/prime_all_00381.csv', header=None)
num_curves = df.shape[0]
mat = [None]*num_curves

# delete duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#               0  1  2  3      4       5         6
# 0  381000028517  0  0  1 -10112  390256  3.641554
# 1  381000078161  1 -1  1  -2398   34660  3.793360
# 2  381000169349  0  0  1  -1814    1540  3.560441
# 3  381000680981  1 -1  1   -777   31038  3.797729
# 4  381001388219  0  0  1  -7138  234012  3.129705

# %%
max_conductor = df[0].max()

sortedlist = df[0].tolist()
sortedlist.sort()
df['primeidx'] = df[0].apply(lambda x: sortedlist.index(x))

# %%
df.head()
# Out:
#               0  1  2  3      4       5         6  primeidx
# 0  381000028517  0  0  1 -10112  390256  3.641554         0
# 1  381000078161  1 -1  1  -2398   34660  3.793360         1
# 2  381000169349  0  0  1  -1814    1540  3.560441         2
# 3  381000680981  1 -1  1   -777   31038  3.797729         3
# 4  381001388219  0  0  1  -7138  234012  3.129705         4

# %%
df.sort_values("primeidx", inplace=True)
x = df["primeidx"].tolist()
y1 = df[6].tolist()

plt.figure(figsize=(24, 16))
plt.scatter(x, y1, color='blue', s=1)
plt.show()

# %%
df.sort_values(0, inplace=True)
x = df[0].tolist()
y1 = df[6].tolist()

plt.figure(figsize=(24, 16))
plt.scatter(x, y1, color='blue', s=1)
plt.show()

# %%
df.sort_values(0, inplace=True)
x = df[0].tolist()
y1 = df[4].tolist()

plt.figure(figsize=(24, 16))
plt.plot(x, y1, color='red')
plt.show()

# %%
samples = np.array(range(len(df[1].tolist())))
xnew = np.linspace(samples.min(), samples.max(), 20)  
plt.plot(xnew,pchip(samples, df[1].tolist() )(xnew))
plt.show()

# %%
samples = np.array(range(len(df[2].tolist())))    
xnew = np.linspace(samples.min(), samples.max(), 20)
plt.plot(xnew,pchip(samples, df[2].tolist() )(xnew))
plt.show()

# %%
samples = np.array(range(len(df[3].tolist())))    
xnew = np.linspace(samples.min(), samples.max(), 20)
plt.plot(xnew,pchip(samples, df[3].tolist() )(xnew))
plt.show()

# %%
samples = np.array(range(len(df[4].tolist())))    
xnew = np.linspace(samples.min(), samples.max(), 20)
plt.plot(xnew,pchip(samples, df[4].tolist() )(xnew))
plt.show()

# %%
samples = np.array(range(len(df[5].tolist())))    
xnew = np.linspace(samples.min(), samples.max(), 20)
plt.plot(xnew,pchip(samples, df[5].tolist() )(xnew))
plt.show()

# %%
samples = np.array(range(len(df[6].tolist())))    
xnew = np.linspace(samples.min(), samples.max(), 20)
plt.plot(xnew,pchip(samples, df[6].tolist() )(xnew))
plt.show()
